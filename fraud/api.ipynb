# %% [markdown]
# <a href="https://colab.research.google.com/github/nxxk23/AI-Engineer/blob/main/fraud/api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# กำหนด URL ของ API (ไม่รวมหมายเลขหน้า)
base_url = 'https://iclaim.inet.co.th/backend-hospital/api/v1/transaction-claim/opd?start_date=2024-08-01&end_date=2024-08-31&limit=50'

# กำหนด headers สำหรับการร้องขอ
headers = {
    'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJob3NwaXRhbF9jb2RlIjoiMTA2ODUiLCJob3NwaXRhbF9pZCI6IjEyZDExODYxLTViMmQtNDQyMC1hM2U4LTVkNTZhZTA3NjhkNCJ9.oNFYeSPzGacQ0ymndzeq5vG9g3gNRz1MFpviuT1qPNU'
}

# รายการเพื่อเก็บข้อมูลทั้งหมด
all_data = []
page = 1
max_pages = 100  # จำนวนหน้าสูงสุดที่ต้องการดึง

while page <= max_pages:
    # สร้าง URL ที่มีหมายเลขหน้าปัจจุบัน
    url = f"{base_url}&page={page}"

    # ส่งคำขอ GET ไปยัง API
    response = requests.get(url, headers=headers)

    # ตรวจสอบสถานะการตอบกลับ
    if response.status_code == 200:
        print(f"Fetching data from page {page}...")
        response_data = response.json()

        # ตรวจสอบว่า 'data' มีอยู่ใน response หรือไม่
        if 'data' in response_data and response_data['data']:
            # เพิ่มข้อมูลที่ดึงได้ลงในรายการ
            all_data.extend(response_data['data'])
            page += 1  # เปลี่ยนไปยังหน้าถัดไป
        else:
            print("No more data found.")
            break  # ออกจากลูปหากไม่มีข้อมูลเพิ่มเติม
    else:
        print("Failed to retrieve data with status code:", response.status_code)
        print("Response:", response.text)
        break  # ออกจากลูปหากเกิดข้อผิดพลาด

# สร้าง DataFrame จากข้อมูลทั้งหมด
if all_data:
    opd = pd.DataFrame(all_data)

    # แสดง DataFrame ในรูปแบบตาราง
    display(opd)
else:
    print("No data available to display.")
# Out:
# Fetching data from page 1...
# Fetching data from page 2...
# Fetching data from page 3...
# Fetching data from page 4...
# Fetching data from page 5...
# Fetching data from page 6...
# Fetching data from page 7...
# Fetching data from page 8...
# Fetching data from page 9...
# Fetching data from page 10...
# Fetching data from page 11...
# Fetching data from page 12...
# Fetching data from page 13...
# Fetching data from page 14...
# Fetching data from page 15...
# Fetching data from page 16...
# Fetching data from page 17...
# Fetching data from page 18...
# Fetching data from page 19...
# Fetching data from page 20...
# Fetching data from page 21...
# Fetching data from page 22...
# Fetching data from page 23...
# Fetching data from page 24...
# Fetching data from page 25...
# Fetching data from page 26...
# Fetching data from page 27...
# Fetching data from page 28...
# Fetching data from page 29...
# Fetching data from page 30...
# Fetching data from page 31...
# ...

# %%
opd.shape
# Out:
# (5000, 16)

# %%
opd.columns
# Out:
# Index(['transaction_uid', 'transaction_no', 'hospital_code', 'hospital_name',
#        'visit_date', 'dx_free_text', 'claim_status', 'discharge_at',
#        'approve_at', 'coma_score', 'icd9', 'vital_sign', 'billing',
#        'order_item', 'icd_10', 'policy_detail'],
#       dtype='object')

# %%
opd['claim_status'].value_counts()
# Out:
# claim_status
# Approve       3529
# Submit         768
# Received       613
# Cancelled       69
# Decline         16
# Processing       5
# Name: count, dtype: int64

# %%
opd.columns
# Out:
# Index(['transaction_uid', 'transaction_no', 'hospital_code', 'hospital_name',
#        'visit_date', 'dx_free_text', 'claim_status', 'discharge_at',
#        'approve_at', 'coma_score', 'icd9', 'vital_sign', 'billing',
#        'order_item', 'icd_10', 'policy_detail'],
#       dtype='object')

# %%
df = opd[opd['claim_status'].isin(['Approve', 'Decline'])]

# %%
df[df['claim_status']=='Approve']['policy_detail'].iloc[4]
# Out:
# {'insurance': 'aia',
#  'policy_no': '00xxxxxx31',
#  'description': '1 หมายเหตุ บริษัท แพนดอร่า โพรดักชั่น จำกัด (สำนักงานใหญ่)\n 2 หมายเหตุ Remark : Hospital General Expenses 12,000, Surgical Fee 15,000, Doctor’s Visit 800/day\n 3 หมายเหตุ Excess of ER will reimburse with HR, Maximum 30,000 / accident\n 4 หมายเหตุ ***Aon Hotline 085-109-8333***\n '}

# %%
df[df['claim_status']=='Decline']['policy_detail'].iloc[4]
# Out:
# {'insurance': 'tli',
#  'policy_no': '82216370',
#  'description': 'บริษัทจะยืนยันความคุ้มครองเมื่อได้รับใบรับรองแพทย์ที่ระบุการวินิจฉัยโรคแล้วเท่านั้น'}

# %%
print(df['claim_status'].iloc[3], df['policy_detail'].iloc[3])
# Out:
# Approve {'insurance': 'aia', 'policy_no': 'T2xxxxxx09', 'description': '1 กรมธรรม์ T1xxxxxx62 สัญญาเพิ่มเติม  ผล ไม่สามารถใช้บริการเรียกร้องสินไหมได้\n 2 กรมธรรม์ T1xxxxxx84 สัญญาเพิ่มเติม H&S ผล ไม่สามารถใช้บริการเรียกร้องสินไหมผ่านโรงพยาบาล เนื่องจากสัญญาเพิ่มเติมสิ้นผลบังคับ\n 3 กรมธรรม์ T2xxxxxx09 สัญญาเพิ่มเติม H&S Plus gold ผล สัญญาเพิ่มเติมมีสิทธิ์ใช้บริการเรียกร้องสินไหม\n '}

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/AIEngineer/fraud/opd_discharge_August_2024.csv')

# %%
matching_rows = opd[opd['transaction_uid'].isin(data['transaction_uid'])]

# %%
# เลือกเฉพาะคอลัมน์ที่ต้องการจาก data
data_columns = data[['transaction_no', 'cid', 'response', 'check_eligible_id', 'hn_or_vn', 'patient']]

# ทำการ merge โดยใช้ 'transaction_no' เป็นคีย์ และเลือก inner join เพื่อให้ได้เฉพาะ rows ที่ตรงกัน
opd_merged = opd.merge(data_columns, on='transaction_no', how='inner')
opd_merged
# Out:
#                            transaction_uid  \
# 0     e9343e43-e291-43c3-9b36-de056f953915
# 1     0ec319c4-f65c-4552-87bf-d9efa2deac14
# 2     651acb93-9aad-4b98-a923-2674644c31b4
# 3     98ea8465-76e9-43e3-ac7d-9ce1bf4b15cc
# 4     ecb8acc2-039a-47e4-ac24-f167741f4e02
# ...                                    ...
# 4995  b8c125e8-f99b-4ebf-8459-b5a376b25f17
# 4996  32162845-6068-49d1-9799-eb135f1a24ee
# 4997  3bbcc8c8-25bc-401f-9235-ede8051c651f
# 4998  9a4e308e-7f1c-423d-8824-a51da4c02a19
# 4999  30bc8728-f13e-40bb-aed7-f1fb44b25477
#
#                             transaction_no hospital_code  \
# 0                               6700600492         41569
# 1             H-OPD-1782-25670831020720752         41556
# 2             H-OPD-1105-25670831020719805         14354
# 3     c41c9c12-3db2-482e-99db-f3d763cbe691         23781
# 4     c741053b-2407-4f9c-8b17-3ede0ca56a36         41345
# ...                                    ...           ...
# ...

# %%
dec = opdx[opdx['claim_status']=='Decline']
dec.tail()
# Out:
#                            transaction_uid  \
# 4095  175c2128-bbf4-41e9-9c57-a4f6413a82c3
# 4138  f1f8027d-44fb-4aed-84fe-9401484e61dc
# 4431  0467a9b4-7bfc-4fc2-ad60-6b343cd2e3a0
# 4555  8930a671-63d9-4f2b-90a1-23399182fbe7
# 4865  6b374543-0857-4411-8b80-d86d716a2607
#
#                             transaction_no hospital_code  \
# 4095  49280c60-8f4c-46d7-b7b6-2c9d6ea074f6         11558
# 4138  976f7b04-63ec-41e3-b872-e9356249a450         11771
# 4431                            6700594742         11558
# 4555                            6700594619         21673
# 4865                            6700594242         14591
#
#                       hospital_name        visit_date  \
# 4095      โรงพยาบาลซีจีเอช พหลโยธิน  2024-08-29 16:30
# 4138  โรงพยาบาลจุฬารัตน์ 3 อินเตอร์  2024-08-29 15:25
# 4431      โรงพยาบาลซีจีเอช พหลโยธิน  2024-08-29 12:55
# 4555       โรงพยาบาล ซีจีเอช สายไหม  2024-08-29 12:00
# 4865         โรงพยาบาลสำโรงการแพทย์  2024-08-29 10:10
#
# ...

# %%
opdx = opd_merged[opd_merged['claim_status'].isin(['Approve', 'Decline'])]

# %%
opdx[opdx['cid']=='3320600614907']
# Out:
#                            transaction_uid transaction_no hospital_code  \
# 4555  8930a671-63d9-4f2b-90a1-23399182fbe7     6700594619         21673
#
#                  hospital_name        visit_date  \
# 4555  โรงพยาบาล ซีจีเอช สายไหม  2024-08-29 12:00
#
#                       dx_free_text claim_status      discharge_at approve_at  \
# 4555  FB at rt. eac with infection      Decline  2024-08-29 12:59
#
#      coma_score  ... vital_sign  \
# 4555         15  ...         []
#
#                                                 billing  \
# 4555  [{'simb_code': '1.2.2', 'simb_description': 'P...
#
#                                              order_item  \
# 4555  [{'initial': '2000', 'discount': '0', 'net_amo...
#
#                                                  icd_10  \
# 4555  [{'code': 'T16', 'dx_name': 'Foreign body in e...
#
#                                           policy_detail            cid  \
# 4555  {'insurance': 'tli', 'policy_no': '86016554', ...  3320600614907
#
# ...

# %%
import json
print(opdx[opdx['cid']=='1100501220507']['claim_status'].iloc[0])
print(opdx[opdx['cid']=='1100501220507']['policy_detail'].iloc[0])
print(opdx[opdx['cid']=='1100501220507']['order_item'].iloc[0])
print(opdx[opdx['cid']=='1100501220507']['icd_10'].iloc[0])
json.loads(opdx[opdx['cid']=='1100501220507']['response'].iloc[0])
# Out:
# Decline
# {'insurance': 'tli', 'policy_no': '80149850', 'description': 'บริษัทจะยืนยันความคุ้มครองเมื่อได้รับใบรับรองแพทย์ที่ระบุการวินิจฉัยโรคแล้วเท่านั้น'}
# ...

# %%
print(opdx[opdx['claim_status']=='Decline']['icd_10'].iloc[[14]])
# Out:
# 2158    [{'code': 'N201', 'dx_name': 'Calculus of uret...
# Name: icd_10, dtype: object

# %%
opd_merged.to_csv('/content/drive/MyDrive/AIEngineer/fraud/opd_insurance_5000.csv', index='False')

# %%
df.head()
# Out:
#                         transaction_uid                        transaction_no  \
# 0  b25f0a54-3e31-4b01-bb7d-2c2f271b26be          H-OPD-1048-25671031022526908
# 2  bef8a8dc-7f9c-4146-b303-0fb02a5413dc                            6700753096
# 3  7667e682-0da0-46fe-9a1a-867c6cf59bc1  147dfc70-4d0b-4ef5-9b9a-ddd7f3229a33
# 4  41410582-74e6-43c7-902a-18aa305a5b16  ea35271f-72ca-4b1d-899a-6745dc3a8b01
# 5  c17f1e2f-c380-43e9-b98d-1508263bbcb0  b7847c2a-10f8-4ab5-8c64-fa0210f2c7c8
#
#   hospital_code                   hospital_name        visit_date  \
# 0         11771   โรงพยาบาลจุฬารัตน์ 3 อินเตอร์  2024-10-31 21:50
# 2         12188                 โรงพยาบาลทักษิณ  2024-10-31 22:40
# 3         11878  โรงพยาบาลจุฬารัตน์ 11 อินเตอร์  2024-10-31 21:50
# 4         14683   โรงพยาบาลกรุงสยามเซนต์คาร์ลอส  2024-10-31 22:20
# 5         11771   โรงพยาบาลจุฬารัตน์ 3 อินเตอร์  2024-10-31 23:10
#
#                                         dx_free_text claim_status  \
# ...

# %%
opd_df[opd_df['transaction_uid']=='6a096e68-8b24-45a7-93e9-553c9bc2e488']
# Out:
# Empty DataFrame
# Columns: [transaction_uid, transaction_no, hospital_code, hospital_name, visit_date, dx_free_text, claim_status, discharge_at, approve_at, coma_score, icd9, vital_sign, billing, order_item, icd_10]
# Index: []

# %%
opd_df[['transaction_uid','hospital_code','hospital_name','visit_date','claim_status','icd_10','billing','order_item']]
# Out:
#                          transaction_uid hospital_code  \
# 0   b4074631-d836-4515-a8ed-8a38fd92bda2         40765
# 1   f710ab0f-963b-4790-abeb-0e372a4a6c49         11648
# 2   14caa91f-8df0-4fef-afea-a13669932a89         11656
# 3   57348e15-e2af-46bb-a95b-1d8da18c9189         11648
# 4   d516553e-7bf0-4e09-a7a9-1b39210309f5         11621
# 5   a6c59dee-56e0-4189-8dd7-54208c52079b         11648
# 6   1cb6e04f-90a2-4185-a0ab-e52c9779c4d3         11558
# 7   e9d55c33-de0f-4a14-8aa8-db5ce9f808b1         11720
# 8   060c9d34-cbfa-40f4-9e91-7fd0c78932b4         11768
# 9   cfe57962-95aa-40d7-bba9-7817a2065df3         41569
# 10  f1468fbd-785b-4340-8aa6-032c0d5190fe         11648
# 11  3cb48fe6-b166-45f8-b208-fe31998ca826         11765
# 12  879f3797-7885-48e8-b463-78a329bbd9c1         14354
# 13  2c834707-777a-4132-8043-a9025ff7dd67         23781
# 14  58a971fb-cf7d-42be-94ca-3f25f68dc89c         11771
# 15  74f287d9-02fd-43ec-9211-ed44ea1a270c         11656
# ...
